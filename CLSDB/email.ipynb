# %%
from sklearn.cluster import KMeans
import torch
from torch.nn import Embedding
from torch.utils.data import DataLoader
import torch.nn as nn
EPS = 1e-15
from torch.nn import Parameter
import pandas as pd
import numpy as np 
device = 'cpu'
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, average_precision_score
from sklearn import metrics
beta = 4.4
gama = 0.5

def predict_acc(recons_edges, true_edges):
    predict_graph = recons_edges
    predict_edges = np.array(predict_graph)
    
    print("预测精确率： ",average_precision_score(true_edges, predict_edges))
    fpr, tpr, _ = metrics.roc_curve(true_edges, predict_edges, pos_label=1)
    auc = metrics.auc(fpr, tpr)
    print("AUC SCORE: ",auc)
    
    #predict_edges[predict_edges>gama] = 1
    #predict_edges[predict_edges<=gama] = 0
    
    #print("预测准确率： ",accuracy_score(true_edges, predict_edges))
    #print("预测精确率： ",precision_score(true_edges, predict_edges, average='macro'))
    #print("召回率： ",recall_score(true_edges, predict_edges, average='macro'))
    #print("F1 SCORE： ",f1_score(true_edges, predict_edges, average='macro'))
    
class reconstruction_graph(nn.Module):
    """给定类簇质心，更新节点嵌入"""
    def __init__(self, ne, alpha=1.0):
        super(reconstruction_graph, self).__init__()
        NE = ne
        self.alpha = alpha
        self.nodes_embedding = Parameter(NE)
        
    def forward(self, cc):
        CC = cc
        # 计算每个节点对每个类簇的注意力分数（以节点为单位）
        norm_squared = torch.sum((self.nodes_embedding.unsqueeze(1) - CC)**2, 2)   # 节点到质心的距离
        numerator = 1.0 / (1.0 + (norm_squared / self.alpha))
        power = float(self.alpha + 1) / 2    # 计算幂
        numerator = numerator**power    # 所有节点
        soft_assignments = (numerator.t() / torch.sum(numerator, 1)).t() #soft assignment using t-distribution
        # torch.sum(numerator, 1) : 对每一行进行相加
        
        # 计算节点之间的类簇相似性（余弦相似性）：值越大越有利于边的形成
        prod = torch.mm(soft_assignments, soft_assignments.t())#分子
        norm = torch.norm(soft_assignments,p=2,dim=1).unsqueeze(0)#分母
        clusters_similar = prod.div(torch.mm(norm.t(),norm))
        
        # 计算节点之间的距离 ： 值越小越有利于边的形成
        nodes_distance = torch.norm(self.nodes_embedding[:, None]-self.nodes_embedding, dim=2, p=2)
        nodes_distance = torch.div(nodes_distance, torch.max(nodes_distance))
        
        # 计算边的形成概率
        distance_similar = torch.div(beta*nodes_distance, clusters_similar)      
        nodes_similar = torch.exp(-distance_similar)
        
        return nodes_similar

class update_nodes_embedding(nn.Module):
    def __init__(self, ne):
        super(update_nodes_embedding, self).__init__()
        NE = ne
        self.reconstruction_module = reconstruction_graph(NE)     # 更新节点嵌入
        self.optimizer = torch.optim.SGD(params=self.reconstruction_module.parameters(), lr=0.4, momentum=0.9)
        
        #self.loss_function = torch.nn.L1Loss(reduction='sum')
        self.loss_function = torch.nn.MSELoss(reduction='sum')
        
    def forward(self, g, cc, edge_train, edge_test):
        CC = cc
        GP = g
        self.reconstruction_module.train()
        for epoch in range(5):
            self.optimizer.zero_grad()
            graph_reconstruction = self.reconstruction_module(CC)
            graph_train = torch.take(graph_reconstruction, edge_train)
            loss = self.loss_function(g, graph_train)
            loss.backward()
            self.optimizer.step()
            #print(f'Epoch: {epoch:02d}, Loss: {loss.item():.4f}')
        recons_test_edges = torch.take(graph_reconstruction, edge_test).detach()
        predict_acc(recons_test_edges, test_edge)
        return self.reconstruction_module.nodes_embedding.detach()
    
####################################### 以最大化预测效果为目标的类型质心更新 ########################################
class ClusteringLayer(nn.Module):
    """给定节点嵌入，更新类簇质心"""
    def __init__(self, cc, alpha=1.0):
        super(ClusteringLayer, self).__init__()
        self.alpha = alpha
        self.cluster_centers = Parameter(cc)
    
    def forward(self, x):
        NE = x
        # 计算每个节点对每个类簇的注意力分数（以节点为单位）
        norm_squared = torch.sum((NE.unsqueeze(1) - self.cluster_centers)**2, 2)   # 节点到质心的距离
        numerator = 1.0 / (1.0 + (norm_squared / self.alpha))
        power = float(self.alpha + 1) / 2    # 计算幂
        numerator = numerator**power    # 所有节点
        soft_assignments = (numerator.t() / torch.sum(numerator, 1)).t() #soft assignment using t-distribution
        # torch.sum(numerator, 1) : 对每一行进行相加
        
        # 计算节点之间的类簇相似性（余弦相似性）：值越大越有利于边的形成
        prod = torch.mm(soft_assignments, soft_assignments.t())#分子
        norm = torch.norm(soft_assignments,p=2,dim=1).unsqueeze(0)#分母
        clusters_similar = prod.div(torch.mm(norm.t(),norm))
        
        # 计算节点之间的距离 ： 值越小越有利于边的形成
        nodes_distance = torch.norm(NE[:, None]-NE, dim=2, p=2)
        nodes_distance = torch.div(nodes_distance, torch.max(nodes_distance))
        
        # 计算边的形成概率
        distance_similar = torch.div(beta*nodes_distance, clusters_similar)      
        nodes_similar = torch.exp(-distance_similar)
        
        return nodes_similar

def find_cluster_centers(ne, ini_cc, g, edge_train, edge_test, num_epochs=5):        
    NE = ne
    CC = ini_cc
    clusteringlayer = ClusteringLayer(CC)
    optimizer = torch.optim.SGD(params=clusteringlayer.parameters(), lr=0.4, momentum=0.9)
    
    #loss_function = torch.nn.L1Loss(reduction='sum')
    loss_function = torch.nn.MSELoss(reduction='sum')
    
    for epoch in range(num_epochs):
        optimizer.zero_grad()
        graph_recons = clusteringlayer(NE)
        graph_train = torch.take(graph_recons, edge_train)
        loss = loss_function(g, graph_train)
        loss.backward()
        optimizer.step()
        #print(f'Epoch: {epoch:02d}, Loss: {loss.item():.4f}')     
    recons_test_edges = torch.take(graph_recons, edge_test).detach()
    predict_acc(recons_test_edges, test_edge)
    return clusteringlayer.cluster_centers.detach()

# %%
def get_graph(filename_adj, nodes_number):
    raw_edges = pd.read_csv(filename_adj,header=None,sep=' ') - 1
    
    drop_self_loop = raw_edges[raw_edges[0] != raw_edges[1]]
    
    graph_np = np.zeros((nodes_number, nodes_number))
    for i in range(drop_self_loop.shape[0]):
        graph_np[drop_self_loop.iloc[i,0], drop_self_loop.iloc[i,1]]=1
        graph_np[drop_self_loop.iloc[i,1], drop_self_loop.iloc[i,0]]=1
    
    posi_edge = np.argwhere(graph_np == 1)
    posi_edge = posi_edge[posi_edge[:,0]<posi_edge[:,1]]         # 只取左上角矩阵
    posi_edge_number = posi_edge.shape[0]
    
    nega_edge = np.argwhere(graph_np == 0) 
    nega_edge = nega_edge[nega_edge[:,0]<nega_edge[:,1]]     # 只取左上角矩阵
    
    positive_index = np.random.choice(range(posi_edge.shape[0]),int(posi_edge_number*0.9),replace=False)
    choose_positive = posi_edge[positive_index]
    posi_not_choose = np.setdiff1d(range(posi_edge.shape[0]), positive_index)
    test_positive = posi_edge[posi_not_choose]
    
    negative_index = np.random.choice(range(nega_edge.shape[0]),int(posi_edge_number*0.9)*4,replace=False)
    choose_negative = nega_edge[negative_index]
    nega_not_choose = np.setdiff1d(range(nega_edge.shape[0]), negative_index)
    test_nega_index = np.random.choice(nega_not_choose,len(posi_not_choose),replace=False)
    test_negative = nega_edge[test_nega_index]
    
    train_posi = [list(choose_positive[i]) for i in range(len(choose_positive))]
    train_nega = [list(choose_negative[i]) for i in range(len(choose_negative))]
    train_index = train_posi + train_nega
    train_mask = [train_index[i][0]*nodes_number+train_index[i][1] for i in range(len(train_index))]
    train_mask = torch.tensor(train_mask)
    
    test_posi = [list(test_positive[i]) for i in range(len(test_positive))]
    test_nega = [list(test_negative[i]) for i in range(len(test_negative))]
    test_index = test_posi + test_nega
    test_mask = [test_index[i][0]*nodes_number+test_index[i][1] for i in range(len(test_index))]
    test_mask = torch.tensor(test_mask)
    
    graph_tensor = torch.from_numpy(graph_np).float()
    train_edge = torch.take(graph_tensor, train_mask)
    test_edge = np.array(torch.take(graph_tensor, test_mask))
    
    return train_edge, test_edge, train_mask, test_mask

# %%
filename = "data/ia-email-univ.mtx"
nodes_number = 1133
train_edge, test_edge, train_mask, test_mask = get_graph(filename, nodes_number)

# %%
len(train_edge),len(test_edge)
# Out:
# (24525, 1092)

# %%
embedding_dim = 12
n_clusters = 24
alpha = 1

ini_embedding = Embedding(nodes_number, embedding_dim, sparse=True)      # 时刻为0时给定随机的嵌入
ini_node_embeddings = ini_embedding.weight.detach()

kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(ini_node_embeddings)
cluster_centers = kmeans.cluster_centers_
cluster_centers = torch.tensor(cluster_centers, dtype=torch.float)

# %%
raw_nodes_embedding = ini_node_embeddings     # t=0时刻的节点嵌入
raw_cluster_centers = cluster_centers     # t=0时刻的类簇质心
for module_epoch in range(200):
    print("######################### 模块循环 ： %d ##########################"%module_epoch)
    update_nodes_module = update_nodes_embedding(raw_nodes_embedding)
    raw_nodes_embedding = update_nodes_module(train_edge, raw_cluster_centers, train_mask, test_mask)
    raw_cluster_centers = find_cluster_centers(raw_nodes_embedding, raw_cluster_centers, train_edge, train_mask, test_mask)
# Out:
# ######################### 模块循环 ： 0 ##########################
# 预测精确率：  0.6240792269118003
# AUC SCORE:  0.6322136349608877
# 预测精确率：  0.6515035797358935
# AUC SCORE:  0.6507097908196809
# ######################### 模块循环 ： 1 ##########################
# 预测精确率：  0.6845155043385068
# AUC SCORE:  0.6647747856539065
# 预测精确率：  0.691098386556835
# AUC SCORE:  0.6797286962122127
# ######################### 模块循环 ： 2 ##########################
# 预测精确率：  0.7334520978978905
# AUC SCORE:  0.7187235841081994
# 预测精确率：  0.751902453132533
# AUC SCORE:  0.7417984945457473
# ######################### 模块循环 ： 3 ##########################
# 预测精确率：  0.7698270143826192
# AUC SCORE:  0.7566081659488253
# 预测精确率：  0.7721789791737117
# AUC SCORE:  0.7573293617249661
# ######################### 模块循环 ： 4 ##########################
# 预测精确率：  0.7834782296749283
# AUC SCORE:  0.7623777321579518
# 预测精确率：  0.7909136722270401
# AUC SCORE:  0.7700257617840035
# ######################### 模块循环 ： 5 ##########################
# 预测精确率：  0.8030644021347007
# AUC SCORE:  0.7799480739041178
# 预测精确率：  0.803029726578934
# AUC SCORE:  0.773363388748004
# ######################### 模块循环 ： 6 ##########################
# 预测精确率：  0.8174609157811832
# AUC SCORE:  0.7857780192945027
# 预测精确率：  0.8232506975856229
# AUC SCORE:  0.7940097143393845
# ######################### 模块循环 ： 7 ##########################
# 预测精确率：  0.8302271014110956
# AUC SCORE:  0.7989473896067302
# 预测精确率：  0.8285018187939306
# AUC SCORE:  0.7939157911685384
# ######################### 模块循环 ： 8 ##########################
# 预测精确率：  0.8384072650902809
# AUC SCORE:  0.8049953709294368
# 预测精确率：  0.8411061261221465
# AUC SCORE:  0.8093225455862819
# ######################### 模块循环 ： 9 ##########################
# 预测精确率：  0.8443063130513258
# AUC SCORE:  0.8114391713292812
# 预测精确率：  0.8443203107961312
# AUC SCORE:  0.8110332890552671
# ######################### 模块循环 ： 10 ##########################
# 预测精确率：  0.8504051945508899
# AUC SCORE:  0.8165009593581023
# 预测精确率：  0.8513828107382423
# AUC SCORE:  0.8172087375384078
# ######################### 模块循环 ： 11 ##########################
# 预测精确率：  0.8539031173647675
# AUC SCORE:  0.8211769915066618
# 预测精确率：  0.8559603784015044
# AUC SCORE:  0.8239208898549557
# ######################### 模块循环 ： 12 ##########################
# 预测精确率：  0.8596059246374169
# AUC SCORE:  0.8272920608085443
# 预测精确率：  0.8615227445016784
# AUC SCORE:  0.8299386815870332
# ######################### 模块循环 ： 13 ##########################
# 预测精确率：  0.8631460841822548
# AUC SCORE:  0.8318573977914637
# 预测精确率：  0.8632560128537724
# AUC SCORE:  0.8309315836788365
# ######################### 模块循环 ： 14 ##########################
# 预测精确率：  0.8654023544475488
# AUC SCORE:  0.8349266728387608
# 预测精确率：  0.8641933016853722
# AUC SCORE:  0.8325685303707282
# ######################### 模块循环 ： 15 ##########################
# 预测精确率：  0.866784233476194
# AUC SCORE:  0.838613157294476
# 预测精确率：  0.8677773462702132
# AUC SCORE:  0.8395523890029384
# ######################### 模块循环 ： 16 ##########################
# 预测精确率：  0.8706706442655633
# AUC SCORE:  0.8427927383971341
# 预测精确率：  0.8717018512127447
# AUC SCORE:  0.8435172885722336
# ######################### 模块循环 ： 17 ##########################
# 预测精确率：  0.8739027087724308
# AUC SCORE:  0.847036053080009
# 预测精确率：  0.874662460292009
# AUC SCORE:  0.8482469911041339
# ######################### 模块循环 ： 18 ##########################
# 预测精确率：  0.8765955443428506
# AUC SCORE:  0.8504977928054851
# 预测精确率：  0.8776554836551989
# AUC SCORE:  0.852476888191174
# ######################### 模块循环 ： 19 ##########################
# 预测精确率：  0.8791292970896678
# AUC SCORE:  0.8534697902829771
# 预测精确率：  0.8782728581155843
# AUC SCORE:  0.8516818956379396
# ######################### 模块循环 ： 20 ##########################
# 预测精确率：  0.8788794554968051
# AUC SCORE:  0.8541775684632827
# 预测精确率：  0.876784308811164
# AUC SCORE:  0.8515611372754228
# ######################### 模块循环 ： 21 ##########################
# 预测精确率：  0.8804561877703664
# AUC SCORE:  0.8578707617169156
# 预测精确率：  0.8791751679345228
# AUC SCORE:  0.8569751371949174
# ######################### 模块循环 ： 22 ##########################
# 预测精确率：  0.8820303531657436
# AUC SCORE:  0.8597928323203048
# 预测精确率：  0.8820544667456449
# AUC SCORE:  0.8595982771806947
# ######################### 模块循环 ： 23 ##########################
# 预测精确率：  0.8841753703177815
# AUC SCORE:  0.862124139596667
# 预测精确率：  0.8834664564906556
# AUC SCORE:  0.8606683304485501
# ######################### 模块循环 ： 24 ##########################
# 预测精确率：  0.8856341393276133
# AUC SCORE:  0.8637443142937649
# 预测精确率：  0.8851160281105706
# AUC SCORE:  0.8627681841967556
# ######################### 模块循环 ： 25 ##########################
# 预测精确率：  0.8876639339607317
# AUC SCORE:  0.866320492694119
# 预测精确率：  0.8847309435801287
# AUC SCORE:  0.8606683304485503
# ######################### 模块循环 ： 26 ##########################
# 预测精确率：  0.889657881669362
# AUC SCORE:  0.8685343960069234
# 预测精确率：  0.887844665128213
# AUC SCORE:  0.8668940949160728
# ######################### 模块循环 ： 27 ##########################
# 预测精确率：  0.8900775495395955
# AUC SCORE:  0.8687121791517396
# 预测精确率：  0.8867356793502172
# AUC SCORE:  0.8635833031437428
# ######################### 模块循环 ： 28 ##########################
# 预测精确率：  0.8918091444107683
# AUC SCORE:  0.8707583625166042
# 预测精确率：  0.8889095349723956
# AUC SCORE:  0.8670651692629714
# ######################### 模块循环 ： 29 ##########################
# 预测精确率：  0.8927722949787477
# AUC SCORE:  0.8719760093386468
# 预测精确率：  0.8890020411168376
# AUC SCORE:  0.8671792188275705
# ######################### 模块循环 ： 30 ##########################
# 预测精确率：  0.8941311309410294
# AUC SCORE:  0.8739685223201707
# 预测精确率：  0.8906293370962969
# AUC SCORE:  0.8680077553703927
# ######################### 模块循环 ： 31 ##########################
# 预测精确率：  0.8938970229797604
# AUC SCORE:  0.8736901072065906
# 预测精确率：  0.8902127225442302
# AUC SCORE:  0.8690710998403306
# ######################### 模块循环 ： 32 ##########################
# 预测精确率：  0.8945901520420282
# AUC SCORE:  0.8752431939245126
# 预测精确率：  0.8908911896537037
# AUC SCORE:  0.8694702733164271
# ######################### 模块循环 ： 33 ##########################
# 预测精确率：  0.895017508469933
# AUC SCORE:  0.8753505346911942
# 预测精确率：  0.891008862851912
# AUC SCORE:  0.8704162138228071
# ######################### 模块循环 ： 34 ##########################
# 预测精确率：  0.8957926612535326
# AUC SCORE:  0.877017670973715
# 预测精确率：  0.8921769255645045
# AUC SCORE:  0.8719391109500999
# ######################### 模块循环 ： 35 ##########################
# 预测精确率：  0.8958791303805432
# AUC SCORE:  0.8770210253726738
# 预测精确率：  0.8919777161278699
# AUC SCORE:  0.8723349300272377
# ######################### 模块循环 ： 36 ##########################
# 预测精确率：  0.8962754790548382
# AUC SCORE:  0.8781850018113754
# 预测精确率：  0.8927293304924739
# AUC SCORE:  0.8733647305075877
# ######################### 模块循环 ： 37 ##########################
# 预测精确率：  0.8960822147931908
# AUC SCORE:  0.8782017738061694
# 预测精确率：  0.8923108735507868
# AUC SCORE:  0.8736330824242913
# ######################### 模块循环 ： 38 ##########################
# 预测精确率：  0.8962325450358708
# AUC SCORE:  0.8791577775094259
# 预测精确率：  0.893102428269009
# AUC SCORE:  0.8746729461015175
# ######################### 模块循环 ： 39 ##########################
# 预测精确率：  0.8957433492182642
# AUC SCORE:  0.8788692991989695
# 预测精确率：  0.8925262540591782
# AUC SCORE:  0.8749010452307155
# ######################### 模块循环 ： 40 ##########################
# 预测精确率：  0.8958337674380075
# AUC SCORE:  0.8796206845657395
# 预测精确率：  0.8930337329193928
# AUC SCORE:  0.8757027465818674
# ######################### 模块循环 ： 41 ##########################
# 预测精确率：  0.8953950273034174
# AUC SCORE:  0.8794563190167585
# 预测精确率：  0.8933575020911224
# AUC SCORE:  0.8768600142226517
# ######################### 模块循环 ： 42 ##########################
# 预测精确率：  0.8951826033262447
# AUC SCORE:  0.8795032806021816
# 预测精确率：  0.8939841001643647
# AUC SCORE:  0.8776080451904629
# ######################### 模块循环 ： 43 ##########################
# 预测精确率：  0.8946138779415264
# AUC SCORE:  0.8794797998094701
# 预测精确率：  0.8937294690505779
# AUC SCORE:  0.878127977029076
# ######################### 模块循环 ： 44 ##########################
# 预测精确率：  0.8941984164299498
# AUC SCORE:  0.8794630278146762
# 预测精确率：  0.8932054489610194
# AUC SCORE:  0.8778361443196608
# ######################### 模块循环 ： 45 ##########################
# 预测精确率：  0.893853183100926
# AUC SCORE:  0.8798185941043082
# 预测精确率：  0.8932274029868881
# AUC SCORE:  0.8788927799916811
# ######################### 模块循环 ： 46 ##########################
# 预测精确率：  0.8937904664886835
# AUC SCORE:  0.88003663003663
# 预测精确率：  0.8930449019445504
# AUC SCORE:  0.8788961343906398
# ######################### 模块循环 ： 47 ##########################
# 预测精确率：  0.8934617590907892
# AUC SCORE:  0.8801137812126822
# 预测精确率：  0.8930649169699152
# AUC SCORE:  0.8796542285553275
# ######################### 模块循环 ： 48 ##########################
# 预测精确率：  0.8933696128979318
# AUC SCORE:  0.8802043499845698
# 预测精确率：  0.8931271895607064
# AUC SCORE:  0.8798118853063909
# ######################### 模块循环 ： 49 ##########################
# 预测精确率：  0.8936710117243597
# AUC SCORE:  0.8806940922325538
# 预测精确率：  0.8935351338203273
# AUC SCORE:  0.8804425123106442
# ######################### 模块循环 ： 50 ##########################
# 预测精确率：  0.8937440019159467
# AUC SCORE:  0.8810764937138564
# 预测精确率：  0.8935138417834898
# AUC SCORE:  0.8807913698023587
# ######################### 模块循环 ： 51 ##########################
# 预测精确率：  0.8940107696182261
# AUC SCORE:  0.8814387688014061
# 预测精确率：  0.8938760688106345
# AUC SCORE:  0.8813247192368072
# ######################### 模块循环 ： 52 ##########################
# 预测精确率：  0.8940272029052052
# AUC SCORE:  0.881801043888956
# 预测精确率：  0.8935892528423491
# AUC SCORE:  0.8814186424076534
# ######################### 模块循环 ： 53 ##########################
# 预测精确率：  0.8940608135321861
# AUC SCORE:  0.8819788270337721
# 预测精确率：  0.8937161352821924
# AUC SCORE:  0.8817272471118625
# ######################### 模块循环 ： 54 ##########################
# 预测精确率：  0.8939732368398935
# AUC SCORE:  0.8820928765983711
# 预测精确率：  0.893660155266601
# AUC SCORE:  0.8819922446296073
# ######################### 模块循环 ： 55 ##########################
# 预测精确率：  0.8940095771750827
# AUC SCORE:  0.8823444565202807
# 预测精确率：  0.8937782389928953
# AUC SCORE:  0.8823310389244455
# ######################### 模块循环 ： 56 ##########################
# 预测精确率：  0.8939586656050973
# AUC SCORE:  0.8827201492036656
# 预测精确率：  0.8936923218708405
# AUC SCORE:  0.8826731876182426
# ######################### 模块循环 ： 57 ##########################
# 预测精确率：  0.8940300587689132
# AUC SCORE:  0.8830991962860095
# 预测精确率：  0.8939203798075996
# AUC SCORE:  0.8831729930631029
# ######################### 模块循环 ： 58 ##########################
# 预测精确率：  0.8943341725955112
# AUC SCORE:  0.8835117873579412
# 预测精确率：  0.8942807479428335
# AUC SCORE:  0.8836191281246226
# ######################### 模块循环 ： 59 ##########################
# 预测精确率：  0.8947881896290857
# AUC SCORE:  0.8840183016007193
# 预测精确率：  0.8946095688770771
# AUC SCORE:  0.8840518455903071
# ######################### 模块循环 ： 60 ##########################
# 预测精确率：  0.8950281794282783
# AUC SCORE:  0.8844107662788981
# 预测精确率：  0.894844647846664
# AUC SCORE:  0.884430892672651
# ######################### 模块循环 ： 61 ##########################
# 预测精确率：  0.8952666018735813
# AUC SCORE:  0.8846422198070549
# 预测精确率：  0.8950102577713476
# AUC SCORE:  0.8845650686310027
# ######################### 模块循环 ： 62 ##########################
# 预测精确率：  0.8952979309423147
# AUC SCORE:  0.8848401293456237
# 预测精确率：  0.8948459004967575
# AUC SCORE:  0.8847059533872721
# ######################### 模块循环 ： 63 ##########################
# 预测精确率：  0.8952940272911614
# AUC SCORE:  0.8849038629258409
# 预测精确率：  0.8948811259011653
# AUC SCORE:  0.8848300661487475
# ######################### 模块循环 ： 64 ##########################
# 预测精确率：  0.8952334553406486
# AUC SCORE:  0.8849675965060579
# 预测精确率：  0.894927995482122
# AUC SCORE:  0.8848736733352118
# ######################### 模块循环 ： 65 ##########################
# 预测精确率：  0.8952972542496536
# AUC SCORE:  0.8851923412362973
# 预测精确率：  0.8950989459111804
# AUC SCORE:  0.8853198083967315
# ######################### 模块循环 ： 66 ##########################
# 预测精确率：  0.8954654649437548
# AUC SCORE:  0.8856653114894872
# 预测精确率：  0.8954118899186307
# AUC SCORE:  0.88576929785721
# ######################### 模块循环 ： 67 ##########################
# 预测精确率：  0.8956717002221433
# AUC SCORE:  0.8859303090072321
# 预测精确率：  0.895751153453457
# AUC SCORE:  0.8860208777791195
# ######################### 模块循环 ： 68 ##########################
# 预测精确率：  0.8959326257557247
# AUC SCORE:  0.8863093560895758
# 预测精确率：  0.8958939050439103
# AUC SCORE:  0.8864603040427216
# ######################### 模块循环 ： 69 ##########################
# 预测精确率：  0.8963194547232237
# AUC SCORE:  0.8867454279542192
# 预测精确率：  0.8963359836968315
# AUC SCORE:  0.8868527687209007
# ######################### 模块循环 ： 70 ##########################
# 预测精确率：  0.8966098864900777
# AUC SCORE:  0.8871177662386452
# 预测精确率：  0.8966382061784254
# AUC SCORE:  0.8872921949845027
# ######################### 模块循环 ： 71 ##########################
# 预测精确率：  0.8967902716341593
# AUC SCORE:  0.8875571925022474
# 预测精确率：  0.8967005087705331
# AUC SCORE:  0.887580673294959
# ######################### 模块循环 ： 72 ##########################
# 预测精确率：  0.896984884063503
# AUC SCORE:  0.8878322532168685
# 预测精确率：  0.8967767421787649
# AUC SCORE:  0.8877450388439398
# ######################### 模块循环 ： 73 ##########################
# 预测精确率：  0.8971266910126255
# AUC SCORE:  0.8882079459002536
# 预测精确率：  0.8970379059271587
# AUC SCORE:  0.8882079459002534
# ######################### 模块循环 ： 74 ##########################
# 预测精确率：  0.8973263142719412
# AUC SCORE:  0.8884595258221631
# 预测精确率：  0.8972047366221213
# AUC SCORE:  0.8884259818325752
# ######################### 模块循环 ： 75 ##########################
# 预测精确率：  0.897430570909094
# AUC SCORE:  0.8887547129305371
# 预测精确率：  0.8973405664991339
# AUC SCORE:  0.888707751345114
# ######################### 模块循环 ： 76 ##########################
# 预测精确率：  0.8976447430328997
# AUC SCORE:  0.8891673040024688
# 预测精确率：  0.8976032227956483
# AUC SCORE:  0.88916394960351
# ######################### 模块循环 ： 77 ##########################
# 预测精确率：  0.8976422727667985
# AUC SCORE:  0.8891773671993451
# 预测精确率：  0.8973275315077064
# AUC SCORE:  0.8889794576607764
# ######################### 模块循环 ： 78 ##########################
# 预测精确率：  0.8973972172630826
# AUC SCORE:  0.8890867984274577
# 预测精确率：  0.8972495391634923
# AUC SCORE:  0.8888218009097129
# ######################### 模块循环 ： 79 ##########################
# 预测精确率：  0.8973646153799262
# AUC SCORE:  0.8890700264326638
# 预测精确率：  0.8972356348708809
# AUC SCORE:  0.8888821800909713
# ######################### 模块循环 ： 80 ##########################
# 预测精确率：  0.8972949817760717
# AUC SCORE:  0.8890935072253754
# 预测精确率：  0.8970026096124764
# AUC SCORE:  0.8887949657180427
# ######################### 模块循环 ： 81 ##########################
# 预测精确率：  0.8969659739646675
# AUC SCORE:  0.8890197104482818
# 预测精确率：  0.8965435758028193
# AUC SCORE:  0.8886037649773914
# ######################### 模块循环 ： 82 ##########################
# 预测精确率：  0.8969296723858033
# AUC SCORE:  0.888982812059735
# 预测精确率：  0.896510434515032
# AUC SCORE:  0.8885635121898858
# ######################### 模块循环 ： 83 ##########################
# 预测精确率：  0.8968803510430582
# AUC SCORE:  0.8888788256920126
# 预测精确率：  0.8967592504704257
# AUC SCORE:  0.8886171825732265
# ######################### 模块循环 ： 84 ##########################
# 预测精确率：  0.896946909353733
# AUC SCORE:  0.8889828120597352
# 预测精确率：  0.8968488713267404
# AUC SCORE:  0.888758067329496
# ######################### 模块循环 ： 85 ##########################
# 预测精确率：  0.8971797105753263
# AUC SCORE:  0.889066672033705
# 预测精确率：  0.8965822475797721
# AUC SCORE:  0.8885668665888447
# ######################### 模块循环 ： 86 ##########################
# 预测精确率：  0.8969071407502971
# AUC SCORE:  0.8891270512149633
# 预测精确率：  0.8959565983869238
# AUC SCORE:  0.8882079459002535
# ######################### 模块循环 ： 87 ##########################
# 预测精确率：  0.8970269382139908
# AUC SCORE:  0.8891874303962217
# 预测精确率：  0.8969256789114717
# AUC SCORE:  0.8886809161534436
# ######################### 模块循环 ： 88 ##########################
# 预测精确率：  0.8975651219137104
# AUC SCORE:  0.8892947711629029
# 预测精确率：  0.8972463181852945
# AUC SCORE:  0.888560157790927
# ######################### 模块循环 ： 89 ##########################
# 预测精确率：  0.896998764300071
# AUC SCORE:  0.8888888888888888
# 预测精确率：  0.8966003472587709
# AUC SCORE:  0.888526613801339
# ######################### 模块循环 ： 90 ##########################
# 预测精确率：  0.8967066060364876
# AUC SCORE:  0.8890599632357875
# 预测精确率：  0.8950197942742253
# AUC SCORE:  0.8873894725543077
# ######################### 模块循环 ： 91 ##########################
# 预测精确率：  0.8968067970363056
# AUC SCORE:  0.8890767352305815
# 预测精确率：  0.8962129367873363
# AUC SCORE:  0.8882918058742235
# ######################### 模块循环 ： 92 ##########################
# 预测精确率：  0.896840959650791
# AUC SCORE:  0.88916394960351
# 预测精确率：  0.896715207694162
# AUC SCORE:  0.8884662346200808
# ######################### 模块循环 ： 93 ##########################
# 预测精确率：  0.8974620211855543
# AUC SCORE:  0.8890901528264166
# 预测精确率：  0.8971085852112255
# AUC SCORE:  0.8883756658481933
# ######################### 模块循环 ： 94 ##########################
# 预测精确率：  0.8967621234792966
# AUC SCORE:  0.8886205369721853
# 预测精确率：  0.8962204992254308
# AUC SCORE:  0.8882045915012947
# ######################### 模块循环 ： 95 ##########################
# 预测精确率：  0.8965799586136651
# AUC SCORE:  0.8888654080961773
# 预测精确率：  0.8952938880861836
# AUC SCORE:  0.8874901045230716
# ######################### 模块循环 ： 96 ##########################
# 预测精确率：  0.8966828664581017
# AUC SCORE:  0.8889023064847241
# 预测精确率：  0.8961464733694641
# AUC SCORE:  0.8882280722940064
# ######################### 模块循环 ： 97 ##########################
# 预测精确率：  0.8969031197199915
# AUC SCORE:  0.8888586992982597
# 预测精确率：  0.8967063475827771
# AUC SCORE:  0.8884897154127923
# ######################### 模块循环 ： 98 ##########################
# 预测精确率：  0.8972383745002386
# AUC SCORE:  0.8886507265628144
# 预测精确率：  0.8969742822019504
# AUC SCORE:  0.8885232594023802
# ######################### 模块循环 ： 99 ##########################
# 预测精确率：  0.896883954283239
# AUC SCORE:  0.8885064874075863
# 预测精确率：  0.8966267562546268
# AUC SCORE:  0.8884494626252869
# ######################### 模块循环 ： 100 ##########################
# 预测精确率：  0.8966698874985075
# AUC SCORE:  0.888459525822163
# 预测精确率：  0.895860997447581
# AUC SCORE:  0.8875404205074535
# ######################### 模块循环 ： 101 ##########################
# 预测精确率：  0.896790277690014
# AUC SCORE:  0.8890834440284989
# 预测精确率：  0.8962966366939935
# AUC SCORE:  0.8882381354908828
# ######################### 模块循环 ： 102 ##########################
# 预测精确率：  0.8968389458494427
# AUC SCORE:  0.8885031330086276
# 预测精确率：  0.8965145593376116
# AUC SCORE:  0.8881777563096245
# ######################### 模块循环 ： 103 ##########################
# 预测精确率：  0.8965326557163319
# AUC SCORE:  0.888479652215916
# 预测精确率：  0.8965231191388423
# AUC SCORE:  0.8881609843148305
# ######################### 模块循环 ： 104 ##########################
# 预测精确率：  0.8961345989958859
# AUC SCORE:  0.8882045915012948
# 预测精确率：  0.8957232723993941
# AUC SCORE:  0.8884159186356989
# ######################### 模块循环 ： 105 ##########################
# 预测精确率：  0.8955160563574436
# AUC SCORE:  0.8882247178950475
# 预测精确率：  0.8945729196596031
# AUC SCORE:  0.8873223845751319
# ######################### 模块循环 ： 106 ##########################
# 预测精确率：  0.8960280143111974
# AUC SCORE:  0.8884997786096687
# 预测精确率：  0.8958701279699509
# AUC SCORE:  0.8875739644970415
# ######################### 模块循环 ： 107 ##########################
# 预测精确率：  0.8974857167097443
# AUC SCORE:  0.8892209743858095
# 预测精确率：  0.8964894744431378
# AUC SCORE:  0.8880938963356546
# ######################### 模块循环 ： 108 ##########################
# 预测精确率：  0.8971435886022743
# AUC SCORE:  0.8888352185055481
# 预测精确率：  0.8969682814542903
# AUC SCORE:  0.8883454762575641
# ######################### 模块循环 ： 109 ##########################
# 预测精确率：  0.897460848653275
# AUC SCORE:  0.888818446510754
# 预测精确率：  0.897061608660038
# AUC SCORE:  0.8884058554388226
# ######################### 模块循环 ： 110 ##########################
# 预测精确率：  0.8973714974799745
# AUC SCORE:  0.8889794576607764
# 预测精确率：  0.8968049220314873
# AUC SCORE:  0.888513196205504
# ######################### 模块循环 ： 111 ##########################
# 预测精确率：  0.8966633008885709
# AUC SCORE:  0.88888553448993
# 预测精确率：  0.8964254465502116
# AUC SCORE:  0.8884997786096687
# ######################### 模块循环 ： 112 ##########################
# 预测精确率：  0.896950532810347
# AUC SCORE:  0.889214265587892
# 预测精确率：  0.896559365576479
# AUC SCORE:  0.8886071193763502
# ######################### 模块循环 ： 113 ##########################
# 预测精确率：  0.896615240987722
# AUC SCORE:  0.8890197104482818
# 预测精确率：  0.8964936593316719
# AUC SCORE:  0.8886708529565672
# ######################### 模块循环 ： 114 ##########################
# 预测精确率：  0.8966417161462364
# AUC SCORE:  0.8891438232097573
# 预测精确率：  0.8964094038485523
# AUC SCORE:  0.888707751345114
# ######################### 模块循环 ： 115 ##########################
# 预测精确率：  0.8964138509159617
# AUC SCORE:  0.8890767352305813
# 预测精确率：  0.896206716847913
# AUC SCORE:  0.8887446497336606
# ######################### 模块循环 ： 116 ##########################
# 预测精确率：  0.896443623753143
# AUC SCORE:  0.8892176199868507
# 预测精确率：  0.8961255902440033
# AUC SCORE:  0.8887681305263722
# ######################### 模块循环 ： 117 ##########################
# 预测精确率：  0.8960507075234154
# AUC SCORE:  0.8889492680701472
# 预测精确率：  0.895911678723157
# AUC SCORE:  0.8887178145419904
# ######################### 模块循环 ： 118 ##########################
# 预测精确率：  0.896186314594434
# AUC SCORE:  0.8892545183753977
# 预测精确率：  0.8958768889585147
# AUC SCORE:  0.8887916113190839
# ######################### 模块循环 ： 119 ##########################
# 预测精确率：  0.8957034579870872
# AUC SCORE:  0.8890431912409934
# 预测精确率：  0.8957505039580453
# AUC SCORE:  0.8888419273034658
# ######################### 模块循环 ： 120 ##########################
# 预测精确率：  0.8958777430396245
# AUC SCORE:  0.8891907847951804
# 预测精确率：  0.8956427312478564
# AUC SCORE:  0.8888419273034657
# ######################### 模块循环 ： 121 ##########################
# 预测精确率：  0.8957233288201499
# AUC SCORE:  0.8891773671993453
# 预测精确率：  0.8955606137890484
# AUC SCORE:  0.8888922432878477
# ######################### 模块循环 ： 122 ##########################
# 预测精确率：  0.8958262503781312
# AUC SCORE:  0.8892109111889333
# 预测精确率：  0.8957181712547361
# AUC SCORE:  0.8889257872774357
# ######################### 模块循环 ： 123 ##########################
# 预测精确率：  0.8957339908494523
# AUC SCORE:  0.889244455178521
# 预测精确率：  0.8954841317700967
# AUC SCORE:  0.8889358504743121
# ######################### 模块循环 ： 124 ##########################
# 预测精确率：  0.8959438174384114
# AUC SCORE:  0.8893618591420789
# 预测精确率：  0.8955805378481819
# AUC SCORE:  0.8890599632357874
# ######################### 模块循环 ： 125 ##########################
# 预测精确率：  0.8956598765357858
# AUC SCORE:  0.8892645815722737
# 预测精确率：  0.8956101252934907
# AUC SCORE:  0.8890968616243341
# ######################### 模块循环 ： 126 ##########################
# 预测精确率：  0.8956979232730176
# AUC SCORE:  0.8893417327483262
# 预测精确率：  0.8955429421416834
# AUC SCORE:  0.8891773671993451
# ######################### 模块循环 ： 127 ##########################
# 预测精确率：  0.8954623525621846
# AUC SCORE:  0.8893182519556146
# 预测精确率：  0.8953044846982525
# AUC SCORE:  0.8892645815722738
# ######################### 模块循环 ： 128 ##########################
# 预测精确率：  0.8956321727296608
# AUC SCORE:  0.8894624911108427
# 预测精确率：  0.8953609692662028
# AUC SCORE:  0.8893115431576969
# ######################### 模块循环 ： 129 ##########################
# 预测精确率：  0.8954877518938107
# AUC SCORE:  0.8894524279139664
# 预测精确率：  0.8953823859998663
# AUC SCORE:  0.8893014799608205
# ######################### 模块循环 ： 130 ##########################
# 预测精确率：  0.8960436397952884
# AUC SCORE:  0.8898516013900628
# 预测精确率：  0.8955013348226067
# AUC SCORE:  0.8892511639764389
# ######################### 模块循环 ： 131 ##########################
# 预测精确率：  0.8961968149606174
# AUC SCORE:  0.8901165989078077
# 预测精确率：  0.8955662182153237
# AUC SCORE:  0.8892914167639442
# ######################### 模块循环 ： 132 ##########################
# 预测精确率：  0.8953704055549379
# AUC SCORE:  0.8895262246910598
# 预测精确率：  0.8931473386820252
# AUC SCORE:  0.8872318158032444
# ######################### 模块循环 ： 133 ##########################
# 预测精确率：  0.8948229320565881
# AUC SCORE:  0.8903145084463765
# 预测精确率：  0.8946033112788468
# AUC SCORE:  0.8894021119295845
# ######################### 模块循环 ： 134 ##########################
# 预测精确率：  0.8955422889829587
# AUC SCORE:  0.8899924861463322
# 预测精确率：  0.8954933236459636
# AUC SCORE:  0.8901233077057253
# ######################### 模块循环 ： 135 ##########################
# 预测精确率：  0.8956620352983111
# AUC SCORE:  0.8903111540474178
# 预测精确率：  0.8953128961557977
# AUC SCORE:  0.8897308430275463
# ######################### 模块循环 ： 136 ##########################
# 预测精确率：  0.8960702601455868
# AUC SCORE:  0.8904990003891102
# 预测精确率：  0.8958411443061731
# AUC SCORE:  0.8898650189858981
# ######################### 模块循环 ： 137 ##########################
# 预测精确率：  0.8965732801271654
# AUC SCORE:  0.8910625394141879
# 预测精确率：  0.8957502018874417
# AUC SCORE:  0.8901501428973957
# ######################### 模块循环 ： 138 ##########################
# 预测精确率：  0.8964685564547452
# AUC SCORE:  0.8905929235599566
# 预测精确率：  0.8961409521586923
# AUC SCORE:  0.8901602060942719
# ######################### 模块循环 ： 139 ##########################
# 预测精确率：  0.8960544158716195
# AUC SCORE:  0.8908411490829073
# 预测精确率：  0.8950856857273377
# AUC SCORE:  0.8897107166337936
# ######################### 模块循环 ： 140 ##########################
# 预测精确率：  0.8962453163728719
# AUC SCORE:  0.8906063411557916
# 预测精确率：  0.8958505422880998
# AUC SCORE:  0.890046156529673
# ######################### 模块循环 ： 141 ##########################
# 预测精确率：  0.8961895573120068
# AUC SCORE:  0.8910055146318883
# 预测精确率：  0.8948810932761362
# AUC SCORE:  0.8892008479920568
# ######################### 模块循环 ： 142 ##########################
# 预测精确率：  0.8960737596097778
# AUC SCORE:  0.8904419756068107
# 预测精确率：  0.8960973758461201
# AUC SCORE:  0.8903950140213874
# ######################### 模块循环 ： 143 ##########################
# 预测精确率：  0.8963273393148655
# AUC SCORE:  0.8910591850152291
# 预测精确率：  0.8946746551356686
# AUC SCORE:  0.8887245233399079
# ######################### 模块循环 ： 144 ##########################
# 预测精确率：  0.896389105587767
# AUC SCORE:  0.8905392531766158
# 预测精确率：  0.8962527158000871
# AUC SCORE:  0.8903044452495004
# ######################### 模块循环 ： 145 ##########################
# 预测精确率：  0.8969035730722658
# AUC SCORE:  0.8912738665485918
# 预测精确率：  0.8955295964055126
# AUC SCORE:  0.8895631230796064
# ######################### 模块循环 ： 146 ##########################
# 预测精确率：  0.8966721247746452
# AUC SCORE:  0.8907371627151847
# 预测精确率：  0.8965966526967056
# AUC SCORE:  0.8906231131505857
# ######################### 模块循环 ： 147 ##########################
# 预测精确率：  0.8966148144908151
# AUC SCORE:  0.8909686162433417
# 预测精确率：  0.8955721493206426
# AUC SCORE:  0.8898952085765272
# ######################### 模块循环 ： 148 ##########################
# 预测精确率：  0.8968262518770167
# AUC SCORE:  0.8907841243006078
# 预测精确率：  0.8963862099879027
# AUC SCORE:  0.8902977364515825
# ######################### 模块循环 ： 149 ##########################
# 预测精确率：  0.897242638448737
# AUC SCORE:  0.891646204833018
# 预测精确率：  0.8958260884589216
# AUC SCORE:  0.8898549557890217
# ######################### 模块循环 ： 150 ##########################
# 预测精确率：  0.8969755182780925
# AUC SCORE:  0.8908679842745777
# 预测精确率：  0.8963995274684337
# AUC SCORE:  0.8902809644567886
# ######################### 模块循环 ： 151 ##########################
# 预测精确率：  0.8961068858198893
# AUC SCORE:  0.8907136819224731
# 预测精确率：  0.8949786547168082
# AUC SCORE:  0.8893886943337492
# ######################### 模块循环 ： 152 ##########################
# 预测精确率：  0.8962925946697804
# AUC SCORE:  0.8906197587516268
# 预测精确率：  0.8954633263047255
# AUC SCORE:  0.8890532544378699
# ######################### 模块循环 ： 153 ##########################
# 预测精确率：  0.8979882205150496
# AUC SCORE:  0.8924915133706341
# 预测精确率：  0.89713737081691
# AUC SCORE:  0.8912939929423446
# ######################### 模块循环 ： 154 ##########################
# 预测精确率：  0.8976610289647833
# AUC SCORE:  0.8915891800507185
# 预测精确率：  0.8977552925993344
# AUC SCORE:  0.8919044935528452
# ######################### 模块循环 ： 155 ##########################
# 预测精确率：  0.8967663132386584
# AUC SCORE:  0.8912436769579628
# 预测精确率：  0.8965237243597876
# AUC SCORE:  0.8912805753465094
# ######################### 模块循环 ： 156 ##########################
# 预测精确率：  0.8970266309231922
# AUC SCORE:  0.8913677897194381
# 预测精确率：  0.8971710825943704
# AUC SCORE:  0.8914248145017376
# ######################### 模块循环 ： 157 ##########################
# 预测精确率：  0.8969210066653807
# AUC SCORE:  0.8914113969059024
# 预测精确率：  0.8964686825795938
# AUC SCORE:  0.891039058621476
# ######################### 模块循环 ： 158 ##########################
# 预测精确率：  0.8973236701384467
# AUC SCORE:  0.891270512149633
# 预测精确率：  0.8972875236135786
# AUC SCORE:  0.891287284144427
# ######################### 模块循环 ： 159 ##########################
# 预测精确率：  0.8965040327270579
# AUC SCORE:  0.8914382320975727
# 预测精确率：  0.8954576287743303
# AUC SCORE:  0.8902910276536649
# ######################### 模块循环 ： 160 ##########################
# 预测精确率：  0.89663749278046
# AUC SCORE:  0.8908445034818662
# 预测精确率：  0.8966228370344748
# AUC SCORE:  0.890878047471454
# ######################### 模块循环 ： 161 ##########################
# 预测精确率：  0.8962150833077157
# AUC SCORE:  0.8918005071851227
# 预测精确率：  0.8947839427972633
# AUC SCORE:  0.8896771726442056
# ######################### 模块循环 ： 162 ##########################
# 预测精确率：  0.896181290832536
# AUC SCORE:  0.8906533027412149
# 预测精确率：  0.8964428295913978
# AUC SCORE:  0.8907036187255968
# ######################### 模块循环 ： 163 ##########################
# 预测精确率：  0.8966175476057783
# AUC SCORE:  0.891743482402823
# 预测精确率：  0.8951971602427038
# AUC SCORE:  0.8900696373223845
# ######################### 模块循环 ： 164 ##########################
# 预测精确率：  0.896727595442108
# AUC SCORE:  0.8910390586214761
# 预测精确率：  0.8965796232866918
# AUC SCORE:  0.8908847562693717
# ######################### 模块循环 ： 165 ##########################
# 预测精确率：  0.8957718194197363
# AUC SCORE:  0.8909920970360531
# 预测精确率：  0.8953124127071805
# AUC SCORE:  0.890307799648459
# ######################### 模块循环 ： 166 ##########################
# 预测精确率：  0.8966351596894422
# AUC SCORE:  0.8907036187255968
# 预测精确率：  0.896446852560704
# AUC SCORE:  0.8905828603630802
# ######################### 模块循环 ： 167 ##########################
# 预测精确率：  0.8958712495580411
# AUC SCORE:  0.8908042506943605
# 预测精确率：  0.8953844079518325
# AUC SCORE:  0.8900562197265495
# ######################### 模块循环 ： 168 ##########################
# 预测精确率：  0.8964952511756521
# AUC SCORE:  0.8905493163734922
# 预测精确率：  0.8964207919117247
# AUC SCORE:  0.8904117860161815
# ######################### 模块循环 ： 169 ##########################
# 预测精确率：  0.8958544805072545
# AUC SCORE:  0.89066672033705
# 预测精确率：  0.8954365427155156
# AUC SCORE:  0.8898750821827746
# ######################### 模块循环 ： 170 ##########################
# 预测精确率：  0.8961846054829323
# AUC SCORE:  0.8904352668088931
# 预测精确率：  0.8961932727885846
# AUC SCORE:  0.8903446980370058
# ######################### 模块循环 ： 171 ##########################
# 预测精确率：  0.8959357899305647
# AUC SCORE:  0.8906063411557917
# 预测精确率：  0.895252180670089
# AUC SCORE:  0.8896302110587826
# ######################### 模块循环 ： 172 ##########################
# 预测精确率：  0.8961271682323537
# AUC SCORE:  0.8903614700317996
# 预测精确率：  0.8959657285145943
# AUC SCORE:  0.8901903956849013
# ######################### 模块循环 ： 173 ##########################
# 预测精确率：  0.8959386664652988
# AUC SCORE:  0.8904755195963987
# 预测精确率：  0.8952942236787662
# AUC SCORE:  0.8895698318775243
# ######################### 模块循环 ： 174 ##########################
# 预测精确率：  0.8960158684316354
# AUC SCORE:  0.8903212172442942
# 预测精确率：  0.89590109647389
# AUC SCORE:  0.890176978089066
# ######################### 模块循环 ： 175 ##########################
# 预测精确率：  0.8960477875260076
# AUC SCORE:  0.8904688107984811
# 预测精确率：  0.8952077402370011
# AUC SCORE:  0.8894960351004308
# ######################### 模块循环 ： 176 ##########################
# 预测精确率：  0.8960362666759035
# AUC SCORE:  0.8902876732547063
# 预测精确率：  0.8959702795397403
# AUC SCORE:  0.8901836868869837
# ######################### 模块循环 ： 177 ##########################
# 预测精确率：  0.8959928731960343
# AUC SCORE:  0.8904050772182641
# 预测精确率：  0.8951485962883641
# AUC SCORE:  0.8895429966858537
# ######################### 模块循环 ： 178 ##########################
# 预测精确率：  0.8960422648173287
# AUC SCORE:  0.8903279260422118
# 预测精确率：  0.8959586048493126
# AUC SCORE:  0.8901400797005192
# ######################### 模块循环 ： 179 ##########################
# 预测精确率：  0.8961426106393431
# AUC SCORE:  0.8903950140213877
# 预测精确率：  0.8953713955567635
# AUC SCORE:  0.8896402742556588
# ######################### 模块循环 ： 180 ##########################
# 预测精确率：  0.8960508885999837
# AUC SCORE:  0.8903379892390881
# 预测精确率：  0.8958185277707402
# AUC SCORE:  0.8900428021307143
# ######################### 模块循环 ： 181 ##########################
# 预测精确率：  0.8961683902286359
# AUC SCORE:  0.8904117860161815
# 预测精确率：  0.8954615748069666
# AUC SCORE:  0.8896838814421232
# ######################### 模块循环 ： 182 ##########################
# 预测精确率：  0.896132578633749
# AUC SCORE:  0.890291027653665
# 预测精确率：  0.8958368384209768
# AUC SCORE:  0.8899723597525795
# ######################### 模块循环 ： 183 ##########################
# 预测精确率：  0.8962844252629409
# AUC SCORE:  0.8903782420265937
# 预测精确率：  0.8956452577328199
# AUC SCORE:  0.8897643870171342
# ######################### 模块循环 ： 184 ##########################
# 预测精确率：  0.8961395018959625
# AUC SCORE:  0.8902876732547063
# 预测精确率：  0.8958269760057238
# AUC SCORE:  0.8899807457499765
# ######################### 模块循环 ： 185 ##########################
# 预测精确率：  0.8964367959692359
# AUC SCORE:  0.8904486844047284
# 预测精确率：  0.8957970241689449
# AUC SCORE:  0.8897442606233814
# ######################### 模块循环 ： 186 ##########################
# 预测精确率：  0.8962441370952071
# AUC SCORE:  0.8903514068349233
# 预测精确率：  0.8959748582397431
# AUC SCORE:  0.8900059037421675
# ######################### 模块循环 ： 187 ##########################
# 预测精确率：  0.8965757516537821
# AUC SCORE:  0.8905023547880689
# 预测精确率：  0.8957834387827366
# AUC SCORE:  0.8897643870171343
# ######################### 模块循环 ： 188 ##########################
# 预测精确率：  0.8963347918356928
# AUC SCORE:  0.8904151404151404
# 预测精确率：  0.8959912821526606
# AUC SCORE:  0.889979068550497
# ######################### 模块循环 ： 189 ##########################
# 预测精确率：  0.8965258458521612
# AUC SCORE:  0.8905291899797394
# 预测精确率：  0.8957635371310345
# AUC SCORE:  0.8897610326181756
# ######################### 模块循环 ： 190 ##########################
# 预测精确率：  0.8964708356512403
# AUC SCORE:  0.8904654563995222
# 预测精确率：  0.8961011554835201
# AUC SCORE:  0.8899555877577856
# ######################### 模块循环 ： 191 ##########################
# 预测精确率：  0.8964815141763778
# AUC SCORE:  0.8905828603630801
# 预测精确率：  0.8956692181909093
# AUC SCORE:  0.8898113486025575
# ######################### 模块循环 ： 192 ##########################
# 预测精确率：  0.8963573574732611
# AUC SCORE:  0.8904654563995222
# 预测精确率：  0.8959449116242549
# AUC SCORE:  0.8899522333588268
# ######################### 模块循环 ： 193 ##########################
# 预测精确率：  0.8964321561008336
# AUC SCORE:  0.8905929235599565
# 预测精确率：  0.8956491682501924
# AUC SCORE:  0.8898046398046399
# ######################### 模块循环 ： 194 ##########################
# 预测精确率：  0.896382517563639
# AUC SCORE:  0.890535898777657
# 预测精确率：  0.8959878886516314
# AUC SCORE:  0.8901333709026016
# ######################### 模块循环 ： 195 ##########################
# 预测精确率：  0.8964060362166091
# AUC SCORE:  0.8906533027412148
# 预测精确率：  0.8956388499760832
# AUC SCORE:  0.8899455245609091
# ######################### 模块循环 ： 196 ##########################
# 预测精确率：  0.8963862764392945
# AUC SCORE:  0.8906298219485033
# 预测精确率：  0.895953564711779
# AUC SCORE:  0.8901736236901071
# ######################### 模块循环 ： 197 ##########################
# 预测精确率：  0.8963829776288671
# AUC SCORE:  0.8907606435078962
# 预测精确率：  0.895623225903946
# AUC SCORE:  0.8899857773484146
# ######################### 模块循环 ： 198 ##########################
# 预测精确率：  0.8964131535106983
# AUC SCORE:  0.8907438715131022
# 预测精确率：  0.895979916168695
# AUC SCORE:  0.8902574836640771
# ######################### 模块循环 ： 199 ##########################
# 预测精确率：  0.896400999747919
# AUC SCORE:  0.8908478578808249
# 预测精确率：  0.8956165760816794
# AUC SCORE:  0.8900864093171784
